# %%
#para saber se um site permite a raspagem de dados, basta ao final, digitar "robots.txt", que será renderizado uma janela com informaçoes
#se der erro, possivelmente é proibida a raspagem de dados.
#modelo: https://pt.wikipedia.org/robots.txt

# %%
import pandas as pd

# %%
url = 'https://pt.wikipedia.org/wiki/Big_Brother_Brasil_21'

# %%
#se aparecer erro de "No tables found", basta tirar as aspas
html = pd.read_html(url, match='Origem')

# %%
bbb21 = html[0]

# %%
bbb21
# Out:
#                                      Participante Data de Nascimento  \
# 0                         Juliette Freire Feitosa         03/12/1989
# 1                   Camilla Jesus Santos de Lucas         13/10/1994
# 2           Filipe Kartalian Ayrosa Galvão (Fiuk)         25/10/1990
# 3                   Gilberto José Nogueira Junior         14/07/1991
# 4              Viviane de Queiroz Pereira (Pocah)         17/10/1994
# 5                           Arthur Louzada Picoli         21/06/1994
# 6            Vitória de Felice Moraes (Viih Tube)         18/08/2000
# 7                      João Luiz Pedrosa da Silva         09/10/1996
# 8                               Caio Farah Afiune         06/01/1989
# 9                                Thaís Faria Braz         25/01/1993
# 10                Rodolffo Matthaus da Silva Rios         24/08/1988
# 11              Sarah Carolline Vieira de Andrade         22/06/1991
# 12                    Carla Carolina Moreira Diaz         28/11/1990
# ...
