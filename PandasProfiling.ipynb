# %%
import pandas as pd

# %%
enem_ms = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/estados/dados_MS_2019.csv', index_col=0)

# %%
enem_ms
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 129      190001743753    2019                4       F                1
# 149      190001743754    2019                4       M                1
# 170      190001743755    2019                2       M                1
# 174      190001743756    2019               12       F                1
# 218      190001743757    2019                4       F                1
# ...               ...     ...              ...     ...              ...
# 5094974  190005947159    2019               15       M                2
# 5095091  190005947160    2019                1       M                1
# 5095127  190005947161    2019               12       F                0
# 5095140  190005947162    2019                2       M                1
# 5095162  190005947163    2019                9       F                0
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
enem_ms.describe()
# Out:
#        NU_INSCRICAO   NU_ANO  TP_FAIXA_ETARIA  TP_ESTADO_CIVIL   TP_COR_RACA  \
# count  7.039300e+04  70393.0     70393.000000     70393.000000  70393.000000
# mean   1.900038e+11   2019.0         5.954370         1.102198      2.096217
# std    1.464779e+06      0.0         4.204663         0.507568      1.103964
# min    1.900011e+11   2019.0         1.000000         0.000000      0.000000
# 25%    1.900027e+11   2019.0         2.000000         1.000000      1.000000
# 50%    1.900040e+11   2019.0         4.000000         1.000000      2.000000
# 75%    1.900049e+11   2019.0        10.000000         1.000000      3.000000
# max    1.900061e+11   2019.0        20.000000         4.000000      5.000000
#
#        TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU     TP_ESCOLA  \
# count      70393.000000     70393.000000     70393.000000  70393.000000
# mean           1.038342         1.561704         2.966389      1.323043
# ...

# %%
pd.get_option("max_columns")
#esse é o limite mostrado no head, por exemplo, de 20 colunas
# Out:
# 80

# %%
pd.set_option('max_columns', 80)

# %%
enem_ms.head()
# Out:
#      NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 129  190001743753    2019                4       F                1
# 149  190001743754    2019                4       M                1
# 170  190001743755    2019                2       M                1
# 174  190001743756    2019               12       F                1
# 218  190001743757    2019                4       F                1
#
#      TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 129            1                 1                1                3
# 149            1                 1                1                2
# 170            3                 1                2                0
# 174            1                 1                1               12
# 218            3                 1                1                3
#
#      TP_ESCOLA  TP_ENSINO  IN_TREINEIRO  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  \
# ...

# %%
# !pip install markupsafe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#deu errado o pip install markupsafe, porque o código soft_unicode foi removido e substituido por soft_str, na atualizaçao 2.1.0.

# %%
from pandas_profiling import ProfileReport

# %%
#assim, o ideal não é pegar a atualização mais recente do markupsafe, mas a versão anterior a 2.1.0
#onde, consultando o:
#https://markupsafe.palletsprojects.com/en/2.1.x/changes/#version-2-1-0
#Remove soft_unicode, which was previously deprecated. Use soft_str instead. #261
#assim, a solucao é baixar a a versao 2.0.1

# %%
#!pip install markupsafe==2.0.1, a foi arrumado reiniciando o kernel

# %%
from pandas_profiling import ProfileReport

# %%
#profile = ProfileReport(enem_ms, minimal=True)

# %%
#profile

# %%
#profile.to_notebook_iframe()

# %%
profile = ProfileReport(enem_ms.sample(n=1000))

# %%
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file('enem_ms_report.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#a versão com html deu certo
#para acessar, ir no arquivo
#se o df for muito grande, vai dar problema
